# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)
'''

from __future__ import print_function

import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("mnist", one_hot=True)

# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
keep_prob: 1.}))
# Out:
# Extracting mnist/train-images-idx3-ubyte.gz
# Extracting mnist/train-labels-idx1-ubyte.gz
# Extracting mnist/t10k-images-idx3-ubyte.gz
# Extracting mnist/t10k-labels-idx1-ubyte.gz
# Iter 1280, Minibatch Loss= 24654.253906, Training Accuracy= 0.30469
# Iter 2560, Minibatch Loss= 17700.328125, Training Accuracy= 0.46094
# Iter 3840, Minibatch Loss= 8687.292969, Training Accuracy= 0.57812
# Iter 5120, Minibatch Loss= 3232.413574, Training Accuracy= 0.73438
# Iter 6400, Minibatch Loss= 5746.958984, Training Accuracy= 0.75000
# Iter 7680, Minibatch Loss= 2909.667969, Training Accuracy= 0.85156
# Iter 8960, Minibatch Loss= 3522.576416, Training Accuracy= 0.84375
# Iter 10240, Minibatch Loss= 2048.364990, Training Accuracy= 0.85156
# Iter 11520, Minibatch Loss= 2904.885010, Training Accuracy= 0.82031
# Iter 12800, Minibatch Loss= 2271.729492, Training Accuracy= 0.85938
# Iter 14080, Minibatch Loss= 2186.221191, Training Accuracy= 0.84375
# Iter 15360, Minibatch Loss= 1572.529297, Training Accuracy= 0.89062
# Iter 16640, Minibatch Loss= 1910.331299, Training Accuracy= 0.85156
# Iter 17920, Minibatch Loss= 1879.645996, Training Accuracy= 0.89062
# Iter 19200, Minibatch Loss= 2011.852539, Training Accuracy= 0.89062
# Iter 20480, Minibatch Loss= 927.200134, Training Accuracy= 0.92969
# Iter 21760, Minibatch Loss= 1727.268433, Training Accuracy= 0.91406
# Iter 23040, Minibatch Loss= 1401.350586, Training Accuracy= 0.90625
# Iter 24320, Minibatch Loss= 973.183350, Training Accuracy= 0.92188
# Iter 25600, Minibatch Loss= 2238.197754, Training Accuracy= 0.86719
# Iter 26880, Minibatch Loss= 1125.697632, Training Accuracy= 0.93750
# Iter 28160, Minibatch Loss= 1113.963135, Training Accuracy= 0.91406
# Iter 29440, Minibatch Loss= 1458.114502, Training Accuracy= 0.89844
# Iter 30720, Minibatch Loss= 725.270203, Training Accuracy= 0.90625
# Iter 32000, Minibatch Loss= 342.519562, Training Accuracy= 0.94531
# Iter 33280, Minibatch Loss= 521.841431, Training Accuracy= 0.92969
# Iter 34560, Minibatch Loss= 344.738037, Training Accuracy= 0.94531
# Iter 35840, Minibatch Loss= 1565.117432, Training Accuracy= 0.89844
# Iter 37120, Minibatch Loss= 952.172791, Training Accuracy= 0.92188
# Iter 38400, Minibatch Loss= 779.620728, Training Accuracy= 0.95312
# Iter 39680, Minibatch Loss= 402.605591, Training Accuracy= 0.95312
# Iter 40960, Minibatch Loss= 834.332092, Training Accuracy= 0.93750
# Iter 42240, Minibatch Loss= 1473.480103, Training Accuracy= 0.90625
# Iter 43520, Minibatch Loss= 361.991791, Training Accuracy= 0.96094
# Iter 44800, Minibatch Loss= 1091.907471, Training Accuracy= 0.90625
# Iter 46080, Minibatch Loss= 629.914246, Training Accuracy= 0.91406
# Iter 47360, Minibatch Loss= 1114.992432, Training Accuracy= 0.92969
# Iter 48640, Minibatch Loss= 1145.734497, Training Accuracy= 0.91406
# Iter 49920, Minibatch Loss= 71.306412, Training Accuracy= 0.98438
# Iter 51200, Minibatch Loss= 561.662170, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 556.945374, Training Accuracy= 0.95312
# Iter 53760, Minibatch Loss= 664.274658, Training Accuracy= 0.93750
# Iter 55040, Minibatch Loss= 183.081573, Training Accuracy= 0.97656
# Iter 56320, Minibatch Loss= 558.625610, Training Accuracy= 0.94531
# Iter 57600, Minibatch Loss= 996.358521, Training Accuracy= 0.93750
# Iter 58880, Minibatch Loss= 484.589050, Training Accuracy= 0.98438
# Iter 60160, Minibatch Loss= 393.608276, Training Accuracy= 0.96094
# Iter 61440, Minibatch Loss= 810.469604, Training Accuracy= 0.92969
# Iter 62720, Minibatch Loss= 863.090942, Training Accuracy= 0.95312
# Iter 64000, Minibatch Loss= 1051.235352, Training Accuracy= 0.95312
# Iter 65280, Minibatch Loss= 947.753418, Training Accuracy= 0.94531
# Iter 66560, Minibatch Loss= 446.396912, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 667.639893, Training Accuracy= 0.92969
# Iter 69120, Minibatch Loss= 775.610413, Training Accuracy= 0.92969
# Iter 70400, Minibatch Loss= 273.500122, Training Accuracy= 0.96875
# Iter 71680, Minibatch Loss= 340.527100, Training Accuracy= 0.96094
# Iter 72960, Minibatch Loss= 327.038513, Training Accuracy= 0.96875
# Iter 74240, Minibatch Loss= 198.570602, Training Accuracy= 0.95312
# Iter 75520, Minibatch Loss= 641.389648, Training Accuracy= 0.95312
# Iter 76800, Minibatch Loss= 136.241730, Training Accuracy= 0.97656
# Iter 78080, Minibatch Loss= 414.769287, Training Accuracy= 0.93750
# Iter 79360, Minibatch Loss= 242.115265, Training Accuracy= 0.96875
# Iter 80640, Minibatch Loss= 51.030602, Training Accuracy= 0.98438
# Iter 81920, Minibatch Loss= 322.514374, Training Accuracy= 0.96875
# Iter 83200, Minibatch Loss= 122.617920, Training Accuracy= 0.98438
# Iter 84480, Minibatch Loss= 604.194885, Training Accuracy= 0.93750
# Iter 85760, Minibatch Loss= 399.157349, Training Accuracy= 0.96094
# Iter 87040, Minibatch Loss= 317.659363, Training Accuracy= 0.95312
# Iter 88320, Minibatch Loss= 397.778046, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 113.643860, Training Accuracy= 0.98438
# Iter 90880, Minibatch Loss= 890.952454, Training Accuracy= 0.92969
# Iter 92160, Minibatch Loss= 118.613235, Training Accuracy= 0.97656
# Iter 93440, Minibatch Loss= 270.119873, Training Accuracy= 0.96875
# Iter 94720, Minibatch Loss= 251.282379, Training Accuracy= 0.96875
# Iter 96000, Minibatch Loss= 119.385612, Training Accuracy= 0.98438
# Iter 97280, Minibatch Loss= 295.188080, Training Accuracy= 0.96094
# Iter 98560, Minibatch Loss= 524.770203, Training Accuracy= 0.96094
# Iter 99840, Minibatch Loss= 199.831543, Training Accuracy= 0.97656
# Iter 101120, Minibatch Loss= 155.776337, Training Accuracy= 0.97656
# Iter 102400, Minibatch Loss= 160.744614, Training Accuracy= 0.97656
# Iter 103680, Minibatch Loss= 332.554962, Training Accuracy= 0.94531
